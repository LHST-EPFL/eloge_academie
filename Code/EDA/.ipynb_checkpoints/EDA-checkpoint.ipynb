# %% [markdown]
# The purpose of this notebook is to explore the data

# %% [markdown]
# # 1. Load and import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DF_PATH = './../Data/Dataframes/'

eulogies = pd.read_csv(DF_PATH + 'eulogies.csv')
sec = pd.read_csv(DF_PATH + 'sec_perp.csv')

# %%
eulogies.head()
# Out:
#                                      Savant      Auteur   Annee Eloge
# 0                       Guillaume Amontons   Fontenelle  1705.0   NaN
# 1  Marc René de Voyer de Paulmy d'Argenson   Fontenelle  1721.0   NaN
# 2                            Claude Berger   Fontenelle  1712.0   NaN
# 3                           Pierre Blondin   Fontenelle  1713.0   NaN
# 4                        Hermann Boerhaave   Fontenelle  1738.0   NaN

# %%
sec.tail()
# Out:
#           Name  Début   Fin  Aux_Début  Aux_Fin  Duree
# 34        Gros   1991  2001        0.0      0.0   10.0
# 35  Le Douarin   2001  2006        0.0      0.0    5.0
# 36        Bach   2006  2015        0.0      0.0    9.0
# 37     Cossart   2016  2021        0.0      0.0    5.0
# 38  Fontenelle   1697  1740        0.0      0.0   43.0

# %% [markdown]
# # 2. Exploring the dataset

# %%
print("Number of eulogies : " + str(eulogies.shape[0]))
# Out:
# Number of eulogies : 390

# %% [markdown]
# ## a. By year

# %%
print("First year of publication : " + str(int(min(eulogies.Annee))))
print("Last year of publication : " + str(int(max(eulogies.Annee))))
# Out:
# First year of publication : 1700
# Last year of publication : 1943

# %%
eulogies['Annee'].value_counts()
# Out:
# 1773.0    25
# 1718.0     8
# 1715.0     8
# 1707.0     8
# 1743.0     6
#           ..
# 1840.0     1
# 1875.0     1
# 1918.0     1
# 1774.0     1
# 1919.0     1
# Name: Annee, Length: 178, dtype: int64

# %%
print('The author the year with the most publications is : ' + 
      eulogies[eulogies['Annee']==1773].reset_index().loc[0, 'Auteur'])
# Out:
# The author the year with the most publications is : Condorcet

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize = (15,16))

nbins = int((max(eulogies.Annee)-min(eulogies.Annee))/10) + 1
nbins_5ann = int((max(eulogies.Annee)-min(eulogies.Annee))/5) + 1


nbins_ann = int((max(eulogies.Annee)-min(eulogies.Annee))) 
#df['Annee'].hist(bins = nbins)
eulogies['Annee'].hist(ax = axes[0])
eulogies['Annee'].hist(bins = nbins, ax = axes[1])
eulogies['Annee'].hist(bins = nbins_5ann, ax = axes[2])
eulogies['Annee'].hist(bins = nbins_ann, ax = axes[3])

for i in range(2):
    axes[i].set_title("Nombre d'éloges par année")
    axes[i].set_xlabel('Année')
    axes[i].set_ylabel("Nombre d'éloges")

plt.subplots_adjust(hspace = 0.3)

# %%
df_fouchy = eulogies[eulogies['Auteur']=='Fouchy']
print('Première éloge de Fouchy :' + str(min(df_fouchy['Annee'])))
print('Dernière éloge de Fouchy :' + str(max(df_fouchy['Annee'])))
# Out:
# Première éloge de Fouchy :1744.0
# Dernière éloge de Fouchy :1756.0

# %%
print('Première éloge :' + str(min(eulogies['Annee'])))
print('Dernière éloge :' + str(max(eulogies['Annee'])))
# Out:
# Première éloge :1700.0
# Dernière éloge :1943.0

# %% [markdown]
# ## b. By author

# %%
print("Number of different authors : " + str(eulogies['Auteur'].nunique()))
# Out:
# Number of different authors : 33

# %%
eulogies['Auteur'].value_counts().plot(kind = 'bar', figsize = (10, 4))
plt.title('Number of eulogies published by each author')
plt.xlabel('Author')
plt.ylabel('Number of eulogies')
# Out:
# Text(0, 0.5, 'Number of eulogies')

# %%
print('Fontenelle was Secretary for ' + str(int(sec.loc[38, 'Duree'])) + ' years')
print('Condorcet was Secretary for ' + str(int(sec.loc[2, 'Duree'])) + ' years')
print('Cuvier was Secretary for ' + str(int(sec.loc[20, 'Duree'])) + ' years')
print('Fouchy was Secretary for ' + str(int(sec.loc[1, 'Duree'])) + ' years')
# Out:
# Fontenelle was Secretary for 43 years
# Condorcet was Secretary for 17 years
# Cuvier was Secretary for 31 years
# Fouchy was Secretary for 33 years

# %%
sec = sec[sec['Début']<=1943]

# %%
sec.sort_values(by='Duree', ascending = False, inplace = True)

sec.plot(x = 'Name', y = 'Duree', kind = 'bar', figsize = (10,4))
plt.title("Nombre d'année en étant secrétaire perpétuel")
plt.xlabel("Secrétaire perpétuel")
plt.ylabel("Nombre d'année")
# Out:
# Text(0, 0.5, "Nombre d'année")

# %%
#Checking if the author is a secretary

eulogies['Sec'] = eulogies['Auteur'].apply(lambda x : x in sec.Name.unique())

# %% [markdown]
# Looking for the eulogies that were not written by secretaries

# %%
eulogies[eulogies['Sec']==False]
# Out:
#                   Savant    Auteur   Annee  \
# 205              Bonnier  Molliard  1923.0
# 220              Piobert     Morin  1871.0
# 263           Schloesing    Lindet  1920.0
# 265                Guyou  Fournier  1921.0
# 266              Humbert     Borel  1922.0
# 267           Carpentier  d'Ocagne  1922.0
# 268               Carnot    Breton  1922.0
# 269               Jordan  Lebesgue  1923.0
# 313         Maurice Levy   Lecornu  1915.0
# 314  Lucas-Championnière    Richet  1913.0
#
#                                                  Eloge    Sec
# 205  \n Bonnier (Gaston- Eugène-Marie), né à Paris ...  False
# 220  \n\tMessieurs, \n\tC'est ordinairement aux Sec...  False
# 263  \n La belle carrière scientifique de J.- J.-Th...  False
# 265  \n I. \t \n Emile Guyou est né, le 25 novembre...  False
# 266  \n I. \t \n Georges Humbert est né à Paris le ...  False
# 267  \n Il serait, sans doute, possible de caractér...  False
# 268  \n Adolphe Carnot, dont le nom, la famille se ...  False
# 269  \n La section de Géométrie vient, à deux repri...  False
# 313  \n Je ne saurais, dans les circonstances actue...  False
# 314  \n Le grand-père de Lucas-Championnière fut un...  False

# %% [markdown]
# - Molliard : https://fr.wikipedia.org/wiki/Marin_Molliard membre de l'Académie des Sciences, botaniste
# - Morin : https://fr.wikipedia.org/wiki/Arthur_Morin membre de l'Académie des Sciences, physicien
# - Lindet : https://www.yumpu.com/fr/document/view/17144116/leon-lindet-academie-des-sciences
# - Fournier : https://fr.wikipedia.org/wiki/Joseph-Xavier_Fournier
# - Borel :
# - d'Ocagne :
# - Breton :
# - Lebesgue :
# - Lecornu :
# - Richet :

# %%
df = eulogies[eulogies['Sec']]
df
# Out:
#                                        Savant          Auteur   Annee  \
# 0                         Guillaume Amontons       Fontenelle  1705.0
# 1    Marc René de Voyer de Paulmy d'Argenson       Fontenelle  1721.0
# 2                              Claude Berger       Fontenelle  1712.0
# 3                             Pierre Blondin       Fontenelle  1713.0
# 4                          Hermann Boerhaave       Fontenelle  1738.0
# ..                                        ...             ...     ...
# 385                                    Ampère           Arago  1839.0
# 386                                   Poisson           Arago  1850.0
# 387                                Gay-Lussac           Arago  1852.0
# 388                                     Malus           Arago  1855.0
# 389                                     Borda  Lefevre-Gineau  1800.0
#
#                                                  Eloge   Sec
# 0                                                  NaN  True
# 1                                                  NaN  True
# 2                                                  NaN  True
# 3                                                  NaN  True
# 4                                                  NaN  True
# ..                                                 ...   ...
# 385  Messieurs, je dois aujourd'hui, conformément à...  True
# 386  Naissance de Poisson. - Sa jeunesse.- son admi...  True
# 387  La biographie dont je vais donner lecture est ...  True
# 388  Naissance de Malus. son éducation littéraire -...  True
# 389  \n \tJean-Charles Borda, de l'Institut nationa...  True
#
# [380 rows x 5 columns]

# %%
eul_sec = eulogies.merge(sec, how = 'left', left_on = 'Auteur', right_on = 'Name')
eul_sec.head()
# Out:
#                                      Savant      Auteur   Annee Eloge   Sec  \
# 0                       Guillaume Amontons   Fontenelle  1705.0   NaN  True
# 1  Marc René de Voyer de Paulmy d'Argenson   Fontenelle  1721.0   NaN  True
# 2                            Claude Berger   Fontenelle  1712.0   NaN  True
# 3                           Pierre Blondin   Fontenelle  1713.0   NaN  True
# 4                        Hermann Boerhaave   Fontenelle  1738.0   NaN  True
#
#          Name   Début     Fin  Aux_Début  Aux_Fin  Duree
# 0  Fontenelle  1697.0  1740.0        0.0      0.0   43.0
# 1  Fontenelle  1697.0  1740.0        0.0      0.0   43.0
# 2  Fontenelle  1697.0  1740.0        0.0      0.0   43.0
# 3  Fontenelle  1697.0  1740.0        0.0      0.0   43.0
# 4  Fontenelle  1697.0  1740.0        0.0      0.0   43.0

# %%
count = pd.DataFrame(eulogies.Auteur.value_counts()).reset_index()
count
# Out:
#              index  Auteur
# 0       Fontenelle     132
# 1        Condorcet      66
# 2           Cuvier      29
# 3           Fouchy      20
# 4         Bertrand      19
# 5         Flourens      15
# 6   Alfred Lacroix      13
# 7           Picard      12
# 8            Arago      12
# 9           Mairan      10
# 10        Delambre      10
# 11       Berthelot       9
# 12           Dumas       8
# 13         Darboux       6
# 14     De Beaumont       5
# 15         Fourier       4
# 16     Van Tieghem       3
# 17          Lassus       2
# 18          Richet       1
# 19          Breton       1
# 20           Jamin       1
# 21        d'Ocagne       1
# 22        Lebesgue       1
# 23        Fournier       1
# 24         Vulpian       1
# 25        Molliard       1
# 26        Lacepède       1
# 27      De Broglie       1
# 28           Borel       1
# 29          Lindet       1
# 30  Lefevre-Gineau       1
# 31         Lecornu       1
# 32           Morin       1

# %%
sec = sec.merge(count, how='left', left_on = 'Name', right_on = 'index')
sec
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree           index  \
# 0          Fontenelle   1697  1740        0.0      0.0   43.0      Fontenelle
# 1            Flourens   1833  1868        0.0      0.0   35.0        Flourens
# 2      Alfred Lacroix   1914  1948        0.0      0.0   34.0  Alfred Lacroix
# 3              Fouchy   1743  1776        0.0      0.0   33.0          Fouchy
# 4          De Broglie   1942  1975        0.0      0.0   33.0      De Broglie
# 5              Cuvier   1799  1801     1803.0   1832.0   31.0          Cuvier
# 6            Bertrand   1874  1900        0.0      0.0   26.0        Bertrand
# 7              Picard   1917  1942        0.0      0.0   25.0          Picard
# 8               Arago   1830  1853        0.0      0.0   23.0           Arago
# 9            Delambre   1800  1802     1803.0   1822.0   21.0        Delambre
# 10        De Beaumont   1853  1874        0.0      0.0   21.0     De Beaumont
# 11          Berthelot   1889  1907        0.0      0.0   18.0       Berthelot
# 12            Darboux   1900  1917        0.0      0.0   17.0         Darboux
# 13          Condorcet   1776  1793        0.0      0.0   17.0       Condorcet
# 14              Dumas   1868  1884        0.0      0.0   16.0           Dumas
# 15            Fourier   1822  1830        0.0      0.0    8.0         Fourier
# 16        Van Tieghem   1908  1914        0.0      0.0    6.0     Van Tieghem
# 17           Lacepède   1795  1797     1801.0   1803.0    4.0        Lacepède
# 18             Lassus   1797  1799        0.0      0.0    2.0          Lassus
# 19              Jamin   1884  1886        0.0      0.0    2.0           Jamin
# 20            Pasteur   1887  1889        0.0      0.0    2.0             NaN
# 21     Lefevre-Gineau   1798  1800        0.0      0.0    2.0  Lefevre-Gineau
# 22              Prony   1796  1798        0.0      0.0    2.0             NaN
# 23             Mairan   1741  1743        0.0      0.0    2.0          Mairan
# 24             Dulong   1832  1833        0.0      0.0    1.0             NaN
# 25            Vulpian   1886  1887        0.0      0.0    1.0         Vulpian
# 26  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0             NaN
# 27       de Lapparent   1907  1908        0.0      0.0    1.0             NaN
# 28          Becquerel   1908  1909        0.0      0.0    1.0             NaN
#
#     Auteur
# 0    132.0
# 1     15.0
# 2     13.0
# 3     20.0
# 4      1.0
# 5     29.0
# 6     19.0
# 7     12.0
# 8     12.0
# 9     10.0
# 10     5.0
# 11     9.0
# 12     6.0
# 13    66.0
# 14     8.0
# 15     4.0
# 16     3.0
# 17     1.0
# 18     2.0
# 19     1.0
# 20     NaN
# 21     1.0
# 22     NaN
# 23    10.0
# 24     NaN
# 25     1.0
# 26     NaN
# 27     NaN
# 28     NaN

# %%
sec['nbr_per_year'] = sec.apply(lambda row : row['Auteur']/row['Duree'], axis = 1)
sec
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree           index  \
# 0          Fontenelle   1697  1740        0.0      0.0   43.0      Fontenelle
# 1            Flourens   1833  1868        0.0      0.0   35.0        Flourens
# 2      Alfred Lacroix   1914  1948        0.0      0.0   34.0  Alfred Lacroix
# 3              Fouchy   1743  1776        0.0      0.0   33.0          Fouchy
# 4          De Broglie   1942  1975        0.0      0.0   33.0      De Broglie
# 5              Cuvier   1799  1801     1803.0   1832.0   31.0          Cuvier
# 6            Bertrand   1874  1900        0.0      0.0   26.0        Bertrand
# 7              Picard   1917  1942        0.0      0.0   25.0          Picard
# 8               Arago   1830  1853        0.0      0.0   23.0           Arago
# 9            Delambre   1800  1802     1803.0   1822.0   21.0        Delambre
# 10        De Beaumont   1853  1874        0.0      0.0   21.0     De Beaumont
# 11          Berthelot   1889  1907        0.0      0.0   18.0       Berthelot
# 12            Darboux   1900  1917        0.0      0.0   17.0         Darboux
# 13          Condorcet   1776  1793        0.0      0.0   17.0       Condorcet
# 14              Dumas   1868  1884        0.0      0.0   16.0           Dumas
# 15            Fourier   1822  1830        0.0      0.0    8.0         Fourier
# 16        Van Tieghem   1908  1914        0.0      0.0    6.0     Van Tieghem
# 17           Lacepède   1795  1797     1801.0   1803.0    4.0        Lacepède
# 18             Lassus   1797  1799        0.0      0.0    2.0          Lassus
# 19              Jamin   1884  1886        0.0      0.0    2.0           Jamin
# 20            Pasteur   1887  1889        0.0      0.0    2.0             NaN
# 21     Lefevre-Gineau   1798  1800        0.0      0.0    2.0  Lefevre-Gineau
# 22              Prony   1796  1798        0.0      0.0    2.0             NaN
# 23             Mairan   1741  1743        0.0      0.0    2.0          Mairan
# 24             Dulong   1832  1833        0.0      0.0    1.0             NaN
# 25            Vulpian   1886  1887        0.0      0.0    1.0         Vulpian
# 26  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0             NaN
# 27       de Lapparent   1907  1908        0.0      0.0    1.0             NaN
# 28          Becquerel   1908  1909        0.0      0.0    1.0             NaN
#
#     Auteur  nbr_per_year
# 0    132.0      3.069767
# 1     15.0      0.428571
# 2     13.0      0.382353
# 3     20.0      0.606061
# 4      1.0      0.030303
# 5     29.0      0.935484
# 6     19.0      0.730769
# 7     12.0      0.480000
# 8     12.0      0.521739
# 9     10.0      0.476190
# 10     5.0      0.238095
# 11     9.0      0.500000
# 12     6.0      0.352941
# 13    66.0      3.882353
# 14     8.0      0.500000
# 15     4.0      0.500000
# 16     3.0      0.500000
# 17     1.0      0.250000
# 18     2.0      1.000000
# 19     1.0      0.500000
# 20     NaN           NaN
# 21     1.0      0.500000
# 22     NaN           NaN
# 23    10.0      5.000000
# 24     NaN           NaN
# 25     1.0      1.000000
# 26     NaN           NaN
# 27     NaN           NaN
# 28     NaN           NaN

# %%
#sec['Name'].fillna(sec['index'], inplace = True)
sec['index'].fillna(sec['Name'], inplace = True)
sec['Auteur'].fillna(0, inplace = True)
sec['nbr_per_year'].fillna(0, inplace = True)
sec
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree  \
# 0          Fontenelle   1697  1740        0.0      0.0   43.0
# 1            Flourens   1833  1868        0.0      0.0   35.0
# 2      Alfred Lacroix   1914  1948        0.0      0.0   34.0
# 3              Fouchy   1743  1776        0.0      0.0   33.0
# 4          De Broglie   1942  1975        0.0      0.0   33.0
# 5              Cuvier   1799  1801     1803.0   1832.0   31.0
# 6            Bertrand   1874  1900        0.0      0.0   26.0
# 7              Picard   1917  1942        0.0      0.0   25.0
# 8               Arago   1830  1853        0.0      0.0   23.0
# 9            Delambre   1800  1802     1803.0   1822.0   21.0
# 10        De Beaumont   1853  1874        0.0      0.0   21.0
# 11          Berthelot   1889  1907        0.0      0.0   18.0
# 12            Darboux   1900  1917        0.0      0.0   17.0
# 13          Condorcet   1776  1793        0.0      0.0   17.0
# 14              Dumas   1868  1884        0.0      0.0   16.0
# 15            Fourier   1822  1830        0.0      0.0    8.0
# 16        Van Tieghem   1908  1914        0.0      0.0    6.0
# 17           Lacepède   1795  1797     1801.0   1803.0    4.0
# 18             Lassus   1797  1799        0.0      0.0    2.0
# 19              Jamin   1884  1886        0.0      0.0    2.0
# 20            Pasteur   1887  1889        0.0      0.0    2.0
# 21     Lefevre-Gineau   1798  1800        0.0      0.0    2.0
# 22              Prony   1796  1798        0.0      0.0    2.0
# 23             Mairan   1741  1743        0.0      0.0    2.0
# 24             Dulong   1832  1833        0.0      0.0    1.0
# 25            Vulpian   1886  1887        0.0      0.0    1.0
# 26  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0
# 27       de Lapparent   1907  1908        0.0      0.0    1.0
# 28          Becquerel   1908  1909        0.0      0.0    1.0
#
#                 index  Auteur  nbr_per_year
# 0          Fontenelle   132.0      3.069767
# 1            Flourens    15.0      0.428571
# 2      Alfred Lacroix    13.0      0.382353
# 3              Fouchy    20.0      0.606061
# 4          De Broglie     1.0      0.030303
# 5              Cuvier    29.0      0.935484
# 6            Bertrand    19.0      0.730769
# 7              Picard    12.0      0.480000
# 8               Arago    12.0      0.521739
# 9            Delambre    10.0      0.476190
# 10        De Beaumont     5.0      0.238095
# 11          Berthelot     9.0      0.500000
# 12            Darboux     6.0      0.352941
# 13          Condorcet    66.0      3.882353
# 14              Dumas     8.0      0.500000
# 15            Fourier     4.0      0.500000
# 16        Van Tieghem     3.0      0.500000
# 17           Lacepède     1.0      0.250000
# 18             Lassus     2.0      1.000000
# 19              Jamin     1.0      0.500000
# 20            Pasteur     0.0      0.000000
# 21     Lefevre-Gineau     1.0      0.500000
# 22              Prony     0.0      0.000000
# 23             Mairan    10.0      5.000000
# 24             Dulong     0.0      0.000000
# 25            Vulpian     1.0      1.000000
# 26  Sylvestre Lacroix     0.0      0.000000
# 27       de Lapparent     0.0      0.000000
# 28          Becquerel     0.0      0.000000

# %%
sec.sort_values(by='nbr_per_year', ascending = False, inplace = True)
sec.plot(x ='Name', y ='nbr_per_year', kind = 'bar', figsize=(10,4))
plt.title("Ratio du nombre d'éloges écrites par secrétaire perpétuel par an")
plt.xlabel("Secrétaire perpétuel")
plt.ylabel("Ratio du nombre d'éloges écrites par an")
# Out:
# Text(0, 0.5, "Ratio du nombre d'éloges écrites par an")

# %%
def with_1943(row):
    if row['Début'] > 1943 :
        return np.nan
    elif row['Fin'] > 1943 :
        return 1943 - row['Début']
    else :
        return row['Duree']

sec['with_1943'] = sec.apply(lambda row : with_1943(row), axis=1)
sec['new_nbr'] = sec.apply(lambda row : row['Auteur']/row['with_1943'], axis = 1)

sec
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree  \
# 23             Mairan   1741  1743        0.0      0.0    2.0
# 13          Condorcet   1776  1793        0.0      0.0   17.0
# 0          Fontenelle   1697  1740        0.0      0.0   43.0
# 25            Vulpian   1886  1887        0.0      0.0    1.0
# 18             Lassus   1797  1799        0.0      0.0    2.0
# 5              Cuvier   1799  1801     1803.0   1832.0   31.0
# 6            Bertrand   1874  1900        0.0      0.0   26.0
# 3              Fouchy   1743  1776        0.0      0.0   33.0
# 8               Arago   1830  1853        0.0      0.0   23.0
# 21     Lefevre-Gineau   1798  1800        0.0      0.0    2.0
# 19              Jamin   1884  1886        0.0      0.0    2.0
# 16        Van Tieghem   1908  1914        0.0      0.0    6.0
# 15            Fourier   1822  1830        0.0      0.0    8.0
# 14              Dumas   1868  1884        0.0      0.0   16.0
# 11          Berthelot   1889  1907        0.0      0.0   18.0
# 7              Picard   1917  1942        0.0      0.0   25.0
# 9            Delambre   1800  1802     1803.0   1822.0   21.0
# 1            Flourens   1833  1868        0.0      0.0   35.0
# 2      Alfred Lacroix   1914  1948        0.0      0.0   34.0
# 12            Darboux   1900  1917        0.0      0.0   17.0
# 17           Lacepède   1795  1797     1801.0   1803.0    4.0
# 10        De Beaumont   1853  1874        0.0      0.0   21.0
# 4          De Broglie   1942  1975        0.0      0.0   33.0
# 20            Pasteur   1887  1889        0.0      0.0    2.0
# 22              Prony   1796  1798        0.0      0.0    2.0
# 24             Dulong   1832  1833        0.0      0.0    1.0
# 26  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0
# 27       de Lapparent   1907  1908        0.0      0.0    1.0
# 28          Becquerel   1908  1909        0.0      0.0    1.0
#
#                 index  Auteur  nbr_per_year  with_1943   new_nbr
# 23             Mairan    10.0      5.000000        2.0  5.000000
# 13          Condorcet    66.0      3.882353       17.0  3.882353
# 0          Fontenelle   132.0      3.069767       43.0  3.069767
# 25            Vulpian     1.0      1.000000        1.0  1.000000
# 18             Lassus     2.0      1.000000        2.0  1.000000
# 5              Cuvier    29.0      0.935484       31.0  0.935484
# 6            Bertrand    19.0      0.730769       26.0  0.730769
# 3              Fouchy    20.0      0.606061       33.0  0.606061
# 8               Arago    12.0      0.521739       23.0  0.521739
# 21     Lefevre-Gineau     1.0      0.500000        2.0  0.500000
# 19              Jamin     1.0      0.500000        2.0  0.500000
# 16        Van Tieghem     3.0      0.500000        6.0  0.500000
# 15            Fourier     4.0      0.500000        8.0  0.500000
# 14              Dumas     8.0      0.500000       16.0  0.500000
# 11          Berthelot     9.0      0.500000       18.0  0.500000
# 7              Picard    12.0      0.480000       25.0  0.480000
# 9            Delambre    10.0      0.476190       21.0  0.476190
# 1            Flourens    15.0      0.428571       35.0  0.428571
# 2      Alfred Lacroix    13.0      0.382353       29.0  0.448276
# 12            Darboux     6.0      0.352941       17.0  0.352941
# 17           Lacepède     1.0      0.250000        4.0  0.250000
# 10        De Beaumont     5.0      0.238095       21.0  0.238095
# 4          De Broglie     1.0      0.030303        1.0  1.000000
# 20            Pasteur     0.0      0.000000        2.0  0.000000
# 22              Prony     0.0      0.000000        2.0  0.000000
# 24             Dulong     0.0      0.000000        1.0  0.000000
# 26  Sylvestre Lacroix     0.0      0.000000        1.0  0.000000
# 27       de Lapparent     0.0      0.000000        1.0  0.000000
# 28          Becquerel     0.0      0.000000        1.0  0.000000

# %%
sec.sort_values(by='new_nbr', ascending = False, inplace = True)
sec.plot(x ='Name', y ='new_nbr', kind = 'bar', figsize=(10,4))

plt.title("Ratio du nombre d'éloges écrites par secrétaire perpétuel par an")
plt.xlabel("Secrétaire perpétuel")
plt.ylabel("Ratio du nombre d'éloges écrites par an")
# Out:
# Text(0, 0.5, "Ratio du nombre d'éloges écrites par an")

# %%
# Vérifier que tous les secrétaires ont une éloge

sec['has_eulogy'] = sec['Name'].apply(lambda x : x in eulogies.Savant.unique())
sec
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree  \
# 23             Mairan   1741  1743        0.0      0.0    2.0
# 13          Condorcet   1776  1793        0.0      0.0   17.0
# 0          Fontenelle   1697  1740        0.0      0.0   43.0
# 25            Vulpian   1886  1887        0.0      0.0    1.0
# 18             Lassus   1797  1799        0.0      0.0    2.0
# 4          De Broglie   1942  1975        0.0      0.0   33.0
# 5              Cuvier   1799  1801     1803.0   1832.0   31.0
# 6            Bertrand   1874  1900        0.0      0.0   26.0
# 3              Fouchy   1743  1776        0.0      0.0   33.0
# 8               Arago   1830  1853        0.0      0.0   23.0
# 15            Fourier   1822  1830        0.0      0.0    8.0
# 14              Dumas   1868  1884        0.0      0.0   16.0
# 11          Berthelot   1889  1907        0.0      0.0   18.0
# 16        Van Tieghem   1908  1914        0.0      0.0    6.0
# 19              Jamin   1884  1886        0.0      0.0    2.0
# 21     Lefevre-Gineau   1798  1800        0.0      0.0    2.0
# 7              Picard   1917  1942        0.0      0.0   25.0
# 9            Delambre   1800  1802     1803.0   1822.0   21.0
# 2      Alfred Lacroix   1914  1948        0.0      0.0   34.0
# 1            Flourens   1833  1868        0.0      0.0   35.0
# 12            Darboux   1900  1917        0.0      0.0   17.0
# 17           Lacepède   1795  1797     1801.0   1803.0    4.0
# 10        De Beaumont   1853  1874        0.0      0.0   21.0
# 20            Pasteur   1887  1889        0.0      0.0    2.0
# 22              Prony   1796  1798        0.0      0.0    2.0
# 24             Dulong   1832  1833        0.0      0.0    1.0
# 26  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0
# 27       de Lapparent   1907  1908        0.0      0.0    1.0
# 28          Becquerel   1908  1909        0.0      0.0    1.0
#
#                 index  Auteur  nbr_per_year  with_1943   new_nbr  has_eulogy
# 23             Mairan    10.0      5.000000        2.0  5.000000       False
# 13          Condorcet    66.0      3.882353       17.0  3.882353        True
# 0          Fontenelle   132.0      3.069767       43.0  3.069767       False
# 25            Vulpian     1.0      1.000000        1.0  1.000000       False
# 18             Lassus     2.0      1.000000        2.0  1.000000        True
# 4          De Broglie     1.0      0.030303        1.0  1.000000       False
# 5              Cuvier    29.0      0.935484       31.0  0.935484        True
# 6            Bertrand    19.0      0.730769       26.0  0.730769        True
# 3              Fouchy    20.0      0.606061       33.0  0.606061       False
# 8               Arago    12.0      0.521739       23.0  0.521739        True
# 15            Fourier     4.0      0.500000        8.0  0.500000        True
# 14              Dumas     8.0      0.500000       16.0  0.500000        True
# 11          Berthelot     9.0      0.500000       18.0  0.500000       False
# 16        Van Tieghem     3.0      0.500000        6.0  0.500000       False
# 19              Jamin     1.0      0.500000        2.0  0.500000       False
# 21     Lefevre-Gineau     1.0      0.500000        2.0  0.500000       False
# 7              Picard    12.0      0.480000       25.0  0.480000        True
# 9            Delambre    10.0      0.476190       21.0  0.476190       False
# 2      Alfred Lacroix    13.0      0.382353       29.0  0.448276       False
# 1            Flourens    15.0      0.428571       35.0  0.428571        True
# 12            Darboux     6.0      0.352941       17.0  0.352941        True
# 17           Lacepède     1.0      0.250000        4.0  0.250000       False
# 10        De Beaumont     5.0      0.238095       21.0  0.238095        True
# 20            Pasteur     0.0      0.000000        2.0  0.000000       False
# 22              Prony     0.0      0.000000        2.0  0.000000       False
# 24             Dulong     0.0      0.000000        1.0  0.000000       False
# 26  Sylvestre Lacroix     0.0      0.000000        1.0  0.000000       False
# 27       de Lapparent     0.0      0.000000        1.0  0.000000       False
# 28          Becquerel     0.0      0.000000        1.0  0.000000       False

# %%
df_no = sec[sec['has_eulogy'] == False]
df_no = df_no[df_no['Fin']<1944]
df_no
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree  \
# 23             Mairan   1741  1743        0.0      0.0    2.0
# 0          Fontenelle   1697  1740        0.0      0.0   43.0
# 25            Vulpian   1886  1887        0.0      0.0    1.0
# 3              Fouchy   1743  1776        0.0      0.0   33.0
# 11          Berthelot   1889  1907        0.0      0.0   18.0
# 16        Van Tieghem   1908  1914        0.0      0.0    6.0
# 19              Jamin   1884  1886        0.0      0.0    2.0
# 21     Lefevre-Gineau   1798  1800        0.0      0.0    2.0
# 9            Delambre   1800  1802     1803.0   1822.0   21.0
# 17           Lacepède   1795  1797     1801.0   1803.0    4.0
# 20            Pasteur   1887  1889        0.0      0.0    2.0
# 22              Prony   1796  1798        0.0      0.0    2.0
# 24             Dulong   1832  1833        0.0      0.0    1.0
# 26  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0
# 27       de Lapparent   1907  1908        0.0      0.0    1.0
# 28          Becquerel   1908  1909        0.0      0.0    1.0
#
#                 index  Auteur  nbr_per_year  with_1943   new_nbr  has_eulogy
# 23             Mairan    10.0      5.000000        2.0  5.000000       False
# 0          Fontenelle   132.0      3.069767       43.0  3.069767       False
# 25            Vulpian     1.0      1.000000        1.0  1.000000       False
# 3              Fouchy    20.0      0.606061       33.0  0.606061       False
# 11          Berthelot     9.0      0.500000       18.0  0.500000       False
# 16        Van Tieghem     3.0      0.500000        6.0  0.500000       False
# 19              Jamin     1.0      0.500000        2.0  0.500000       False
# 21     Lefevre-Gineau     1.0      0.500000        2.0  0.500000       False
# 9            Delambre    10.0      0.476190       21.0  0.476190       False
# 17           Lacepède     1.0      0.250000        4.0  0.250000       False
# 20            Pasteur     0.0      0.000000        2.0  0.000000       False
# 22              Prony     0.0      0.000000        2.0  0.000000       False
# 24             Dulong     0.0      0.000000        1.0  0.000000       False
# 26  Sylvestre Lacroix     0.0      0.000000        1.0  0.000000       False
# 27       de Lapparent     0.0      0.000000        1.0  0.000000       False
# 28          Becquerel     0.0      0.000000        1.0  0.000000       False

# %%
eulogies.Savant[eulogies.Savant == 'de Fouchy'] = 'Fouchy'
# Out:
# <ipython-input-41-94e254bbc5a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eulogies.Savant[eulogies.Savant == 'de Fouchy'] = 'Fouchy'

# %%
eulogies[eulogies.Savant == 'Laparrent'] = 'de Lapparent'

# %%
eulogies[eulogies.Savant == 'Lacépède'] = 'Lacepède'

# %%
df_dup = eulogies[eulogies.duplicated(subset = 'Savant', keep = False)]
df_dup
# Out:
#                                        Savant      Auteur   Annee  \
# 0                         Guillaume Amontons   Fontenelle  1705.0
# 1    Marc René de Voyer de Paulmy d'Argenson   Fontenelle  1721.0
# 2                              Claude Berger   Fontenelle  1712.0
# 3                             Pierre Blondin   Fontenelle  1713.0
# 4                          Hermann Boerhaave   Fontenelle  1738.0
# ..                                        ...         ...     ...
# 364                                    Picard  De Broglie  1942.0
# 375                                    Cuvier    Flourens  1834.0
# 380                                de Jussieu    Flourens  1838.0
# 381                                    Cuvier    Flourens  1840.0
# 388                                     Malus       Arago  1855.0
#
#                                                  Eloge   Sec
# 0                                                  NaN  True
# 1                                                  NaN  True
# 2                                                  NaN  True
# 3                                                  NaN  True
# 4                                                  NaN  True
# ..                                                 ...   ...
# 364  \n Messieurs, \t\n Dans notre Compagnie, il es...  True
# 375  \n\tLorsqu'une nation perd un de ces hommes do...  True
# 380  La famille des Jussieu est originaire du petit...  True
# 381  Parmi les hommes auxquels nos Eloges sont cons...  True
# 388  Naissance de Malus. son éducation littéraire -...  True
#
# [147 rows x 5 columns]

# %%
eulogies[eulogies['Auteur']=='Poincarre']
# Out:
# Empty DataFrame
# Columns: [Savant, Auteur, Annee, Eloge, Sec]
# Index: []

# %%
eulogies[eulogies['Auteur'] == 'Cuvier']
# Out:
#            Savant  Auteur   Annee  \
# 2      Desessarts  Cuvier  1812.0
# 3       Cavendish  Cuvier  1812.0
# 8       Daubenton  Cuvier  1800.0
# 9       Lemonnier  Cuvier  1800.0
# 10       Héritier  Cuvier  1801.0
# 11        Gilbert  Cuvier  1801.0
# 12         Darcet  Cuvier  1802.0
# 14      Priestley  Cuvier  1805.0
# 16    Martin Cels  Cuvier  1806.0
# 17        Adanson  Cuvier  1807.0
# 21    Broussonnet  Cuvier  1808.0
# 23         Lassus  Cuvier  1809.0
# 24       Ventenat  Cuvier  1809.0
# 26       Fourcroy  Cuvier  1811.0
# 138         Banks  Cuvier  1821.0
# 140       Duhamel  Cuvier  1822.0
# 142       Richard  Cuvier  1828.0
# 143        Thouin  Cuvier  1828.0
# 145          Hauy  Cuvier  1823.0
# 146    Berthollet  Cuvier  1824.0
# 148        Ramond  Cuvier  1826.0
# 149         Halle  Cuvier  1827.0
# 150     Corvisart  Cuvier  1827.0
# 151         Pinel  Cuvier  1827.0
# 153          Bosc  Cuvier  1829.0
# 154  Humphry Davy  Cuvier  1830.0
# 155     Vauquelin  Cuvier  1821.0
# 240       Lamarck  Cuvier  1822.0
#
#                                                  Eloge   Sec
# 2    Jean-Charles Desessarts, médecin, membre de l'...  True
# 3    Parmi les hommes que nous avons coutume de cél...  True
# 8    Louis-Jean-Marie Daubenton, membre du Sénat co...  True
# 9    Si l'Institut national ne publie point ordinai...  True
# 10   Les hommes dont la classe de physique vous a r...  True
# 11   Certaines personnes trouveront peut-être quelq...  True
# 12   Nous l'avouons, ce n'est pas sans crainte que ...  True
# 14   Messieurs, \n\tJ'ai à vous entretenir de la vi...  True
# 16   Jacques-Martin Cels, cultivateur-botaniste, me...  True
# 17   Lorsque nous paraissons à cette tribune, c'est...  True
# 21   \n \tPierre-Marie-Auguste Broussonnet, profess...  True
# 23   \n \tLes éloges publics de l'Institut ne sont ...  True
# 24   \n \t…tienne-Pierre Ventenat, membre de l'Inst...  True
# 26   \n \tL'histoire de cette longue suite d'hommes...  True
# 138  \n\tLes ouvrages que laisse après lui l'homme ...  True
# 140  \n\tPrononcé dans la séance publique de l'Acad...  True
# 142  \n\tM. Richard nous offre l'exemple d'un accor...  True
# 143  \n\tRien ne prouve mieux à quel point l'existe...  True
# 145  \n\tL'histoire des sciences présente quelques ...  True
# 146  \n\tQuelque grande, quelque heureuse qu'ait ét...  True
# 148  \n\tDans cette biographie de l'un de nos plus ...  True
# 149  \n\tDe tout temps l'ancienne Académie des Scie...  True
# 150  \n\tJean-Nicolas Corvisart, le confrère et l'a...  True
# 151  \n\tPhilippe Pinel a été presqu'en toute chose...  True
# 153  \n\tLouis-Augustin Guillaume Bosc, longtemps c...  True
# 154  \n\tUn célèbre académicien, parvenu de l'état ...  True
# 155  \n\tLe juste respect que l'Académie porte à la...  True
# 240  \n\tParmi les hommes livrés à la noble occupat...  True

# %%
sec[sec['Auteur']==0]
# Out:
#                  Name  Début   Fin  Aux_Début  Aux_Fin  Duree  \
# 19            Pasteur   1887  1889        0.0      0.0    2.0
# 20     Lefevre-Gineau   1798  1800        0.0      0.0    2.0
# 21              Prony   1796  1798        0.0      0.0    2.0
# 23             Dulong   1832  1833        0.0      0.0    1.0
# 24  Sylvestre Lacroix   1802  1803        0.0      0.0    1.0
# 26       de Lapparent   1907  1908        0.0      0.0    1.0
# 27          Becquerel   1908  1909        0.0      0.0    1.0
#
#                 index  Auteur  nbr_per_year  has_eulogy  with_1943  new_nbr
# 19            Pasteur     0.0           0.0       False        2.0      0.0
# 20     Lefevre-Gineau     0.0           0.0       False        2.0      0.0
# 21              Prony     0.0           0.0       False        2.0      0.0
# 23             Dulong     0.0           0.0       False        1.0      0.0
# 24  Sylvestre Lacroix     0.0           0.0       False        1.0      0.0
# 26       de Lapparent     0.0           0.0        True        1.0      0.0
# 27          Becquerel     0.0           0.0       False        1.0      0.0

# %%
eulogies[eulogies['Auteur']=='Condorcet']
# Out:
#             Savant     Auteur   Annee  \
# 33   de la Chambre  Condorcet  1773.0
# 34        Frenicle  Condorcet  1773.0
# 35          Picard  Condorcet  1773.0
# 36        Mariotte  Condorcet  1773.0
# 37          Duclos  Condorcet  1773.0
# ..             ...        ...     ...
# 111      Fougeroux  Condorcet  1789.0
# 112    de Fourcroy  Condorcet  1804.0
# 113         Turgot  Condorcet  1789.0
# 114   de L'Hôpital  Condorcet  1777.0
# 115         Pascal  Condorcet  1778.0
#
#                                                  Eloge   Sec
# 33   [Condorcet avait mis, en marge de cette premiè...  True
# 34   Nicolas Frenicle de Bessy, conseiller à la cou...  True
# 35   [Voyez sur Picard l’Histoire céleste. Il a sou...  True
# 36   Edme Mariotte naquit à Dijon, ou du moins il y...  True
# 37   Samuel Cotreau Duclos, médecin ordinaire du ro...  True
# ..                                                 ...   ...
# 111  Auguste Denis Fougeroux, de l’Institut de Bolo...  True
# 112  Charles-René de Fourcroy, maréchal de camp, gr...  True
# 113  Étienne-François Turgot, associé libre de l’Ac...  True
# 114  Chancelier de France. Discours présenté à L’ac...  True
# 115  Blaise Pascal naquit à Clermont, en Auvergne, ...  True
#
# [66 rows x 5 columns]

# %% [markdown]
# # 3. EDA
#
# https://neptune.ai/blog/exploratory-data-analysis-natural-language-processing-tools
#
# https://www.stat4decision.com/fr/traitement-langage-naturel-francais-tal-nlp/

# %% [markdown]
# ### Nombre de caractères

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

df['Eloge'].str.len().hist(ax = axes)
plt.title('Nombre de caractères par éloge')
plt.xlabel('Nombre de caractères')
plt.ylabel("Nombre d'éloges")
# Out:
# Text(0, 0.5, 'Nombre d éloge')

# %% [markdown]
# ### Nombre de mots

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, sharex=True, sharey=True)

df['Eloge'].str.split().map(lambda x : len(x)).hist()

plt.title("Nombre de mots par éloge")
plt.xlabel("Nombre de mots")
plt.ylabel("Nombre d'éloges")
# Out:
# Text(0, 0.5, "Nombre d'éloges")

# %% [markdown]
# - Tokenize
# - Remove stop-words
# - Lemmatize or stemming
# - Representation as vectors (Bag of words, TF-IDF, embeddings)
#
#
#
# - Separate by century or significant period
# - Topic modelling using LDA(Latent Dirichlet Allocation) : each document represented by a list of topics and each topic represented by a list of words
# - WordCloud : size and color of each word that appears in the wordcloud indicates its frequency and importance
# - Textblob : library where the sentiment function returns two properties : polarity 1 means positive statement, -1 negative one and subjectivity how someone's judgement is shaped by personal opinions and feelings
# - Named entity recognition : text classified in pre-defined entities to get insights of the type of entities present in the data
# - Part Of Speech : assigns nature des mots to words

# %% [markdown]
# https://www.linkedin.com/pulse/using-nlp-lda-map-evolution-neural-information-systems-roy-cfa
